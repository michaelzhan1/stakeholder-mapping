# %%
import cv2
import gymnasium as gym
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv, VecMonitor

# Create the environment
env = gym.make("CartPole-v1", render_mode="rgb_array")

# Wrap the environment to record video
env = DummyVecEnv([lambda: env])
env = VecMonitor(env)
video_length = 1000  # Length of the video in steps

# Create the video recorder (specify save path and video length)
video_folder = 'videos/'
env = VecVideoRecorder(env, video_folder=video_folder,
                       record_video_trigger=lambda x: x == 0,  # record the first episode
                       video_length=video_length, name_prefix="cartpole_a2c")

# Train the model
model = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)

# Reset the environment
obs = env.reset()
for i in range(video_length):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)

    # Render each frame (Optional if not viewing)
    env.render("human")

# Close the environment and the video recorder
env.close()
cv2.destroyAllWindows()
# Out:
# Using cpu device
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 26.3        |
# |    ep_rew_mean        | 26.3        |
# | time/                 |             |
# |    fps                | 444         |
# |    iterations         | 100         |
# |    time_elapsed       | 1           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -0.679      |
# |    explained_variance | -0.13046217 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | 1.72        |
# |    value_loss         | 9.81        |
# ---------------------------------------
# Saving video to c:\Users\Michael\Code\stakeholder-mapping\backend\videos\cartpole_a2c-step-0-to-step-1000.mp4
# Moviepy - Building video c:\Users\Michael\Code\stakeholder-mapping\backend\videos\cartpole_a2c-step-0-to-step-1000.mp4.
# Moviepy - Writing video c:\Users\Michael\Code\stakeholder-mapping\backend\videos\cartpole_a2c-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready c:\Users\Michael\Code\stakeholder-mapping\backend\videos\cartpole_a2c-step-0-to-step-1000.mp4
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 28.8       |
# |    ep_rew_mean        | 28.8       |
# | time/                 |            |
# |    fps                | 363        |
# |    iterations         | 200        |
# |    time_elapsed       | 2          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -0.654     |
# |    explained_variance | 0.06434828 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 1.5        |
# |    value_loss         | 8.29       |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 29.4        |
# |    ep_rew_mean        | 29.4        |
# | time/                 |             |
# |    fps                | 494         |
# |    iterations         | 300         |
# |    time_elapsed       | 3           |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -0.619      |
# |    explained_variance | -0.16286027 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | 1.74        |
# |    value_loss         | 7.92        |
# ---------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 32.6         |
# |    ep_rew_mean        | 32.6         |
# | time/                 |              |
# |    fps                | 601          |
# |    iterations         | 400          |
# |    time_elapsed       | 3            |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -0.666       |
# |    explained_variance | -0.008626342 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | -3.64        |
# |    value_loss         | 114          |
# ----------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 34.8         |
# |    ep_rew_mean        | 34.8         |
# | time/                 |              |
# |    fps                | 692          |
# |    iterations         | 500          |
# |    time_elapsed       | 3            |
# |    total_timesteps    | 2500         |
# | train/                |              |
# |    entropy_loss       | -0.57        |
# |    explained_variance | -0.053491235 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 499          |
# |    policy_loss        | 0.72         |
# |    value_loss         | 5.81         |
# ----------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 37.6        |
# |    ep_rew_mean        | 37.6        |
# | time/                 |             |
# |    fps                | 770         |
# |    iterations         | 600         |
# |    time_elapsed       | 3           |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -0.603      |
# |    explained_variance | 0.033391356 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | 1.05        |
# |    value_loss         | 4.88        |
# ---------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 39.3         |
# |    ep_rew_mean        | 39.3         |
# | time/                 |              |
# |    fps                | 837          |
# |    iterations         | 700          |
# |    time_elapsed       | 4            |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -0.513       |
# |    explained_variance | -0.001945138 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | 0.779        |
# |    value_loss         | 4.39         |
# ----------------------------------------
# ------------------------------------------
# | rollout/              |                |
# |    ep_len_mean        | 41             |
# |    ep_rew_mean        | 41             |
# | time/                 |                |
# |    fps                | 896            |
# |    iterations         | 800            |
# |    time_elapsed       | 4              |
# |    total_timesteps    | 4000           |
# | train/                |                |
# |    entropy_loss       | -0.532         |
# |    explained_variance | -0.00031495094 |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 799            |
# |    policy_loss        | 0.536          |
# |    value_loss         | 3.88           |
# ------------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 43.4        |
# |    ep_rew_mean        | 43.4        |
# | time/                 |             |
# |    fps                | 945         |
# |    iterations         | 900         |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -0.398      |
# |    explained_variance | 0.012321353 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | 1.96        |
# |    value_loss         | 3.41        |
# ---------------------------------------
# ------------------------------------------
# | rollout/              |                |
# |    ep_len_mean        | 45.1           |
# |    ep_rew_mean        | 45.1           |
# | time/                 |                |
# |    fps                | 989            |
# |    iterations         | 1000           |
# |    time_elapsed       | 5              |
# |    total_timesteps    | 5000           |
# | train/                |                |
# |    entropy_loss       | -0.571         |
# |    explained_variance | -0.00015544891 |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 999            |
# |    policy_loss        | -14.8          |
# |    value_loss         | 1.21e+03       |
# ------------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 46.8         |
# |    ep_rew_mean        | 46.8         |
# | time/                 |              |
# |    fps                | 1028         |
# |    iterations         | 1100         |
# |    time_elapsed       | 5            |
# |    total_timesteps    | 5500         |
# | train/                |              |
# |    entropy_loss       | -0.603       |
# |    explained_variance | 0.0010187626 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1099         |
# |    policy_loss        | 0.723        |
# |    value_loss         | 2.61         |
# ----------------------------------------
# ------------------------------------------
# | rollout/              |                |
# |    ep_len_mean        | 49             |
# |    ep_rew_mean        | 49             |
# | time/                 |                |
# |    fps                | 1062           |
# |    iterations         | 1200           |
# |    time_elapsed       | 5              |
# |    total_timesteps    | 6000           |
# | train/                |                |
# |    entropy_loss       | -0.558         |
# |    explained_variance | -0.00023770332 |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1199           |
# |    policy_loss        | 0.639          |
# |    value_loss         | 2.22           |
# ------------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 52.3          |
# |    ep_rew_mean        | 52.3          |
# | time/                 |               |
# |    fps                | 1095          |
# |    iterations         | 1300          |
# |    time_elapsed       | 5             |
# |    total_timesteps    | 6500          |
# | train/                |               |
# |    entropy_loss       | -0.507        |
# |    explained_variance | -0.0005390644 |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1299          |
# |    policy_loss        | -26.7         |
# |    value_loss         | 3.07e+03      |
# -----------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 54.7          |
# |    ep_rew_mean        | 54.7          |
# | time/                 |               |
# |    fps                | 1125          |
# |    iterations         | 1400          |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 7000          |
# | train/                |               |
# |    entropy_loss       | -0.475        |
# |    explained_variance | -7.712841e-05 |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1399          |
# |    policy_loss        | 0.471         |
# |    value_loss         | 1.53          |
# -----------------------------------------
# ------------------------------------------
# | rollout/              |                |
# |    ep_len_mean        | 57.1           |
# |    ep_rew_mean        | 57.1           |
# | time/                 |                |
# |    fps                | 1153           |
# |    iterations         | 1500           |
# |    time_elapsed       | 6              |
# |    total_timesteps    | 7500           |
# | train/                |                |
# |    entropy_loss       | -0.497         |
# |    explained_variance | -0.00076544285 |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1499           |
# |    policy_loss        | 0.316          |
# |    value_loss         | 1.22           |
# ------------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 59.4          |
# |    ep_rew_mean        | 59.4          |
# | time/                 |               |
# |    fps                | 1178          |
# |    iterations         | 1600          |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 8000          |
# | train/                |               |
# |    entropy_loss       | -0.504        |
# |    explained_variance | 0.00021064281 |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1599          |
# |    policy_loss        | -29.4         |
# |    value_loss         | 4.52e+03      |
# -----------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 61.6          |
# |    ep_rew_mean        | 61.6          |
# | time/                 |               |
# |    fps                | 1201          |
# |    iterations         | 1700          |
# |    time_elapsed       | 7             |
# |    total_timesteps    | 8500          |
# | train/                |               |
# |    entropy_loss       | -0.409        |
# |    explained_variance | 3.0219555e-05 |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1699          |
# |    policy_loss        | 0.201         |
# |    value_loss         | 0.71          |
# -----------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 63.9          |
# |    ep_rew_mean        | 63.9          |
# | time/                 |               |
# |    fps                | 1221          |
# |    iterations         | 1800          |
# |    time_elapsed       | 7             |
# |    total_timesteps    | 9000          |
# | train/                |               |
# |    entropy_loss       | -0.464        |
# |    explained_variance | 1.4722347e-05 |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1799          |
# |    policy_loss        | 0.319         |
# |    value_loss         | 0.499         |
# -----------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 67.4     |
# |    ep_rew_mean        | 67.4     |
# | time/                 |          |
# |    fps                | 1238     |
# |    iterations         | 1900     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.408   |
# |    explained_variance | 0.0      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -43.2    |
# |    value_loss         | 6.36e+03 |
# ------------------------------------
# ------------------------------------------
# | rollout/              |                |
# |    ep_len_mean        | 70             |
# |    ep_rew_mean        | 70             |
# | time/                 |                |
# |    fps                | 1256           |
# |    iterations         | 2000           |
# |    time_elapsed       | 7              |
# |    total_timesteps    | 10000          |
# | train/                |                |
# |    entropy_loss       | -0.42          |
# |    explained_variance | -3.5762787e-07 |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1999           |
# |    policy_loss        | 0.0713         |
# |    value_loss         | 0.183          |
# ------------------------------------------
# Saving video to c:\Users\Michael\Code\stakeholder-mapping\backend\videos\cartpole_a2c-step-10000-to-step-11000.mp4
# Moviepy - Building video c:\Users\Michael\Code\stakeholder-mapping\backend\videos\cartpole_a2c-step-10000-to-step-11000.mp4.
# Moviepy - Writing video c:\Users\Michael\Code\stakeholder-mapping\backend\videos\cartpole_a2c-step-10000-to-step-11000.mp4
# Moviepy - Done !
# Moviepy - video ready c:\Users\Michael\Code\stakeholder-mapping\backend\videos\cartpole_a2c-step-10000-to-step-11000.mp4
